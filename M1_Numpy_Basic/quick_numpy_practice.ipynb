# %%
# # NumPy 30秒快速練習題
# 這些練習題設計用於快速驗證 NumPy 的核心概念理解，每題應該能在 30 秒內想出解法。

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## M1: ndarray 基礎

# %%
# 練習 1.1: 基本陣列建立
# 任務：建立一個包含 1-5 的一維陣列
# 提示：使用 np.array()
arr1 = [1, 2, 3, 4, 5]
arr1np = np.array(arr1)

# %%
# 練習 1.2: 陣列屬性檢查
# 任務：建立一個 2x3 陣列，並檢查其維度、形狀和數據類型
# 提示：使用 .ndim, .shape, .dtype
arr2 = np.array([[0, 1, 2], [3, 4, 5]])
print(arr2)
print(arr2.ndim)
print(arr2.shape)
print(arr2.dtype)
# Out:
# [[0 1 2]
#  [3 4 5]]
# 2
# (2, 3)
# int64

# %%
# 練習 1.3: 簡單運算
# 任務：將陣列 [1, 2, 3, 4, 5] 中的所有元素乘 2
# 提示：使用陣列乘法
arr3 = np.array([1, 2, 3, 4, 5])
arr3 *= 2
arr3
# Out:
# array([ 2,  4,  6,  8, 10])

# %% [markdown]
# ## M2: 陣列建立方式

# %%
# 練習 2.1: 特殊陣列
# 任務：建立一個 3x3 的單位矩陣
# 提示：使用 np.eye()
identity_matrix = np.eye(3)
identity_matrix
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
# 練習 2.2: 等差數列
# 任務：建立 0 到 10 間隔為 2 的陣列
# 提示：使用 np.arange()
sequence = np.arange(0, 12, 2)
sequence
# Out:
# array([ 0,  2,  4,  6,  8, 10])

# %%
# 練習 2.3: 隨機數陣列
# 任務：生成 5 個 0-1 之間的隨機數
# 提示：使用 np.random.rand()
random_array = np.random.rand(5)
random_array
# Out:
# array([0.36773801, 0.39780374, 0.63636899, 0.87313475, 0.62757544])

# %% [markdown]
# ## M3: 索引與切片

# %%
# 練習 3.1: 基本切片
# 任務：從陣列 [1, 2, 3, 4, 5] 中取出前三個元素
arr = np.array([1, 2, 3, 4, 5])
first_three = arr[:3]
first_three
# Out:
# array([1, 2, 3])

# %%
# 練習 3.2: 條件索引
# 任務：找出陣列 [2, 4, 6, 8, 10] 中大於 5 的元素
arr = np.array([2, 4, 6, 8, 10])
greater_than_five = arr[arr > 5]
greater_than_five
# Out:
# array([ 6,  8, 10])

# %%
# 練習 3.3: 二維切片
# 任務：從 2x3 矩陣中取出第一列
arr = np.array([[1, 2, 3], [4, 5, 6]])
first_row = arr[:, 0]
first_row
# Out:
# array([1, 4])

# %% [markdown]
# ## M4: Broadcasting

# %%
# 練習 4.1: 標量廣播
# 任務：將陣列 [1, 2, 3] 中的每個元素加 5
arr = np.array([1, 2, 3])
result1 = arr + 5
result1
# Out:
# array([6, 7, 8])

# %%
# 練習 4.2: 一維廣播
# 任務：將向量 [10, 20, 30] 加到矩陣的每一列
matrix = np.array([[1, 2, 3], [4, 5, 6]])
vector = np.array([10, 20, 30])
result2 = matrix + vector
result2
# Out:
# array([[11, 22, 33],
#        [14, 25, 36]])

# %%
# 練習 4.3: 形狀擴展
# 任務：將一維陣列 [1, 2, 3] 轉為列向量（3x1 矩陣）
arr = np.array([1, 2, 3])
col_vector = arr.reshape(3, -1)
col_vector
# Out:
# array([[1],
#        [2],
#        [3]])

# %% [markdown]
# ## M5: 數學函數

# %%
# 練習 5.1: 基本數學運算
# 任務：計算陣列 [1, 4, 9, 16] 的平方根
arr = np.array([1, 4, 9, 16])
sqrt_result = np.sqrt(arr)
sqrt_result
# Out:
# array([1., 2., 3., 4.])

# %%
# 練習 5.2: 統計函數
# 任務：計算陣列 [1, 2, 3, 4, 5] 的平均值和標準差
arr = np.array([1, 2, 3, 4, 5])
mean = np.mean(arr)
std = np.std(arr)
print(mean)
print(std)
# Out:
# 3.0
# 1.4142135623730951

# %%
# 練習 5.3: 三角函數
# 任務：計算角度 [0, π/2, π] 的正弦值
angles = np.array([0, np.pi/2, np.pi])
sin_values = np.sin(arr)
sin_values
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 , -0.95892427])

# %% [markdown]
# ## M6: 統計分析應用

# %%
# 練習 6.1: 數據標準化
# 任務：將數據 [1, 2, 3, 4, 5] 標準化（減均值除以標準差）
data = np.array([1, 2, 3, 4, 5])
standardized = (data - np.mean(data))/np.std(data)
standardized
# Out:
# array([-1.41421356, -0.70710678,  0.        ,  0.70710678,  1.41421356])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 練習 6.2: 相關係數
# 任務：計算兩組數據的相關係數
x = np.array([1, 2, 3, 4, 5])

y = np.array([2, 4, 5, 4, 5])
correlation = np.corrcoef(x, y)
# correlation = np.sum(np.multiply((x - np.mean(x)), (y - np.mean(y)))) / (np.sqrt(np.sum(np.pow(x - np.mean(x), 2))) * np.sqrt(np.sum(np.pow(y - np.mean(y), 2))))
print(correlation)
# Out:
# [[1.         0.77459667]
#  [0.77459667 1.        ]]

# %%
# 練習 6.3: 簡單統計描述
# 任務：計算數據 [1, 2, 3, 4, 5] 的基本統計量（平均值、中位數、標準差、最小值、最大值）
data = np.array([1, 2, 3, 4, 5])
stats = {
    "mean":np.mean(data), 
    "median":np.median(data), 
    "std":np.std(data), 
    "min":min(data), 
    "max":max(data)
}
print(stats)
# Out:
# {'mean': np.float64(3.0), 'median': np.float64(3.0), 'std': np.float64(1.4142135623730951), 'min': np.int64(1), 'max': np.int64(5)}
